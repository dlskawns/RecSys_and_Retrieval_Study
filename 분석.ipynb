# %% [markdown]
# <a href="https://colab.research.google.com/github/dlskawns/RecSys_and_Retrieval_Study/blob/main/%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/[AIB] Section Survey (TypeForm).xlsx')

# %%
df
# Out:
#    개인 정보 수집 동의        휴대폰 번호    기수     연령   성별        최종학력  \
# 0          비동의           NaN   NaN     NaN  NaN        NaN
# 1           동의  8.210649e+11  12.0  30~35세   남성  대학원 졸업 이상
# 2           동의  8.210871e+11  12.0  26~29세   남성     대학교 졸업
# 3           동의  8.210908e+11  12.0  30~35세   남성     대학교 졸업
# 4           동의  8.210502e+11  12.0  30~35세   남성     대학교 졸업
# ..         ...           ...   ...     ...  ...        ...
# 63          동의  8.210568e+11  11.0  20~25세   남성    고등학교 졸업
# 64          동의  8.210392e+11  12.0  30~35세   남성     대학교 졸업
# 65          동의  8.210359e+11   9.0  30~35세   남성     대학교 졸업
# 66          동의  8.210721e+11  12.0  26~29세   남성  대학원 졸업 이상
# 67          동의  8.210494e+11  11.0  30~35세   남성  대학원 졸업 이상
#
#                        전공  타사 프로그램 수강여부 타사 프로그램 만족도  지원 소요시간   ...  \
# 0                      NaN          NaN          NaN      NaN  ...
# 1   전공자(컴퓨터, 통계, 수학, 전산 등)    수강 경험 없음.          NaN     4~7일  ...
# ...

# %%
df.columns
# Out:
# Index(['개인 정보 수집 동의', '휴대폰 번호', '기수', '연령 ', '성별 ', '최종학력', '전공 ',
#        '타사 프로그램 수강여부', '타사 프로그램 만족도 ', '지원 소요시간 ', '자기주도학습 점수 ', '근무 희망 분야 ',
#        'Section0 소요시간', 'Section0 이해도 점수 ', 'Section0 심리적 안전감 점수 ',
#        'Section0 Part1 도움된 항목 ', 'Section0 Part1 개선필요 항목',
#        'Section0 Part1 만족도 점수', 'Section0 Part1 추가의견',
#        'Section0 Part2 도움된 항목 ', 'Section0 Part2 개선필요 항목',
#        'Section0 Part2 만족도 점수 ', 'Section0 Part2 추가의견 ', '기타의견', 'name',
#        'userid', 'email', 'Submitted At', 'Token'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# df = df.drop(index = 0)

df = df[df['개인 정보 수집 동의']=='동의']
df = df.drop(columns = ['휴대폰 번호', 'Token','개인 정보 수집 동의'])
df = df[(df['기수']==11) | (df['기수'] == 12)]

# %%
df
# Out:
#       기수     연령  성별        최종학력                     전공  타사 프로그램 수강여부  \
# 1   12.0  30~35세  남성  대학원 졸업 이상  전공자(컴퓨터, 통계, 수학, 전산 등)    수강 경험 없음.
# 2   12.0  26~29세  남성     대학교 졸업        비 전공자(공학계열, 이공계)    수강 경험 없음.
# 3   12.0  30~35세  남성     대학교 졸업        비 전공자(공학계열, 이공계)    수강 경험 없음.
# 4   12.0  30~35세  남성     대학교 졸업        비 전공자(공학계열, 이공계)    수강 경험 없음.
# 5   12.0  26~29세  여성     대학교 졸업  전공자(컴퓨터, 통계, 수학, 전산 등)    수강 경험 없음.
# ..   ...     ...  ..        ...                     ...          ...
# 62  11.0  26~29세  남성     대학교 졸업  전공자(컴퓨터, 통계, 수학, 전산 등)    수강 경험 없음.
# 63  11.0  20~25세  남성    고등학교 졸업            비 전공자(인문계 등)    수강 경험 없음.
# 64  12.0  30~35세  남성     대학교 졸업            비 전공자(인문계 등)    수강 경험 없음.
# 66  12.0  26~29세  남성  대학원 졸업 이상            비 전공자(인문계 등)       패스트캠퍼스
# 67  11.0  30~35세  남성  대학원 졸업 이상  전공자(컴퓨터, 통계, 수학, 전산 등)    수강 경험 없음.
#
#    타사 프로그램 만족도  지원 소요시간  자기주도학습 점수        근무 희망 분야   ...  \
# 1           NaN     4~7일         2점              기타  ...
# ...

# %% [markdown]
# 타사프로그램 경험자 수 분포

# %%
df.columns
# Out:
# Index(['기수', '연령 ', '성별 ', '최종학력', '전공 ', '타사 프로그램 수강여부', '타사 프로그램 만족도 ',
#        '지원 소요시간 ', '자기주도학습 점수 ', '근무 희망 분야 ', 'Section0 소요시간',
#        'Section0 이해도 점수 ', 'Section0 심리적 안전감 점수 ', 'Section0 Part1 도움된 항목 ',
#        'Section0 Part1 개선필요 항목', 'Section0 Part1 만족도 점수',
#        'Section0 Part1 추가의견', 'Section0 Part2 도움된 항목 ',
#        'Section0 Part2 개선필요 항목', 'Section0 Part2 만족도 점수 ',
#        'Section0 Part2 추가의견 ', '기타의견', 'name', 'userid', 'email',
#        'Submitted At'],
#       dtype='object')

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
# %matplotlib inline
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())

print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.2.2
# 설치 위치:  /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py
# 설정 위치:  /root/.config/matplotlib
# 캐시 위치:  /root/.cache/matplotlib

# %%
font_list = fm.findSystemFonts()

# %%
font_list
# Out:
# ['/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf',
#  '/usr/share/fonts/truetype/humor-sans/Humor-Sans.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf',
# ...

# %%
from matplotlib import font_manager,rc
font_path="/Users/codestates/Downloads/korean.ttf"
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-167cc9d12631> in <module>()
#       1 from matplotlib import font_manager,rc
#       2 font_path="/Users/codestates/Downloads/korean.ttf"
# ----> 3 font_name=font_manager.FontProperties(fname=font_path).get_name()
#       4 rc('font',family=font_name)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/font_manager.py in get_name(self)
#     687         Return the name of the font that best matches the font properties.
#     688         """
# --> 689         return get_font(findfont(self)).family_name
#     690
#     691     def get_style(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1327         hinting_factor = rcParams['text.hinting_factor']
#    1328     return _get_font(os.fspath(filename), hinting_factor,
# ...

# %%
import warnings
import matplotlib as mpl

# warnings.simplefilter(action='ignore', category=FutureWarning)
# mpl.rc("font", family='AppleGothic')
plt.hist(df['타사 프로그램 수강여부']);
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54744 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50630 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
rc('font', family='ssibal')

plt.rcParams['axes.unicode_minus'] = False

# %%
from matplotlib import font_manager, rc

font_fname = ''
font_name = font_manager.FontProperties(fname=font_fname).get_name()

# rc('font', family=font_name)
print(font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-740822e23f1a> in <module>()
#       2
#       3 font_fname = './Users/codestates/Downloads/korean.ttf'
# ----> 4 font_name = font_manager.FontProperties(fname=font_fname).get_name()
#       5
#       6 # rc('font', family=font_name)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/font_manager.py in get_name(self)
#     687         Return the name of the font that best matches the font properties.
#     688         """
# --> 689         return get_font(findfont(self)).family_name
#     690
#     691     def get_style(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1327         hinting_factor = rcParams['text.hinting_factor']
#    1328     return _get_font(os.fspath(filename), hinting_factor,
# ...
